# %% [markdown]
# <a href="https://colab.research.google.com/github/mkjubran/AI-Assisted-Physical-Rehabilitation-using-Pause-Detection/blob/main/AI_Assisted_Physical_Therapy_using_Pause_Detection_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load some libraries needed for the execution of the code

# %%
import os
import numpy as np

# %% [markdown]
# Load the dataset from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Read all .npz files in the folder PHVideoDataSet_2D3D_Blurred/3D/ into a dictionary PHV3DB

# %%
PHV3DB={} #PHVideoDataSet_2D3D_Blurred/3D
directory = '/content/drive/MyDrive/PHVideoDataSet_2D3D_Blurred/3D/'
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
       a = np.load(f)
       PHV3DB[filename.split('_a')[0]]=a['reconstruction'][0,:,:,:]

# %% [markdown]
# Read all .npz files in the folder PHVideoDataSet_2D3D_Blurred/2D/ into a dictionary PHV2DB

# %%
PHV2DB={} #PHVideoDataSet_2D3D_Blurred/2D
directory = '/content/drive/MyDrive/PHVideoDataSet_2D3D_Blurred/2D/'
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):
       a = np.load(f)
       PHV2DB[filename.split('_a')[0]]=a['reconstruction'][0,:,:,:]

# %% [markdown]
# compute the energy in PHV2DB and PHV3DB and then plot a sample exercises. This wil be used later for motion segmentation.

# %%
PHV2DB_Energy={}
for k in PHV2DB.keys():
   PHV2DB_Energy[k]=np.square(PHV2DB[k]-PHV2DB[k][0]).sum(axis=1).sum(axis=1)

# %%
PHV3DB_Energy={}
for k in PHV3DB.keys():
   PHV3DB_Energy[k]=np.square(PHV3DB[k]-PHV3DB[k][0]).sum(axis=1).sum(axis=1)

# %%
E_name='E8_P8_T0_C0'

# %%
import matplotlib.pyplot as plt
plt.plot(PHV3DB_Energy[E_name])

# %%
for k in PHV3DB.keys():
  while PHV3DB_Energy[k][PHV3DB_Energy[k].argmax()] > 10:
    PHV3DB_Energy[k][PHV3DB_Energy[k].argmax()]=PHV3DB_Energy[k][PHV3DB_Energy[k].argmax()-1]

# %%
for k in PHV2DB.keys():
  while PHV2DB_Energy[k][PHV2DB_Energy[k].argmax()] > 1e6:
    PHV2DB_Energy[k][PHV2DB_Energy[k].argmax()]=PHV2DB_Energy[k][PHV2DB_Energy[k].argmax()-1]

# %%
import matplotlib.pyplot as plt
plt.plot(PHV3DB_Energy[E_name])

# %% [markdown]
# Use Gaussina Filter to smooth the signal

# %%
def gkernel_1D(l=3, sig=1):
    """\
    Gaussian Kernel Creator via given length and sigma
    """

    ax = np.linspace(-(l - 1) / 2., (l - 1) / 2., l)

    kernel = np.exp(-0.5 * (np.square(ax)) / np.square(sig))

    return kernel / np.sum(kernel)

# %% [markdown]
# Apply Gaussian filter to smoothen PHV2DB

# %%
b = gkernel_1D(7,1)
PHV2DBsmooth=PHV2DB.copy()
for k in PHV2DB.keys():
  for joint_cnt in range(PHV2DB[k].shape[1]):
    for axis_cnt in range(PHV2DB[k].shape[2]):
      PHV2DBsmooth[k][:,joint_cnt,axis_cnt]= np.convolve(PHV2DB[k][:,joint_cnt,axis_cnt],b)[3:-3] # floor of 5/2

# %% [markdown]
# Apply Gaussian filter to smoothen PHV3DB

# %%
b = gkernel_1D(7,1)
PHV3DBsmooth=PHV3DB.copy()
for k in PHV3DB.keys():
  for joint_cnt in range(PHV3DB[k].shape[1]):
    for axis_cnt in range(PHV3DB[k].shape[2]):
      PHV3DBsmooth[k][:,joint_cnt,axis_cnt]= np.convolve(PHV3DB[k][:,joint_cnt,axis_cnt],b)[3:-3] # floor of 5/2

# %% [markdown]
# Compute the energy in smoothed verison of PHV2DB and PHV3DB and then plot a sample exercises. This wil be used later for motion segmentation.

# %%
PHV2DBsmooth_Energy={}
for k in PHV2DBsmooth.keys():
   PHV2DBsmooth_Energy[k]=np.square(PHV2DBsmooth[k]).sum(axis=1).sum(axis=1)[3:-3]

# %%
PHV3DBsmooth_Energy={}
for k in PHV3DBsmooth.keys():
   PHV3DBsmooth_Energy[k]=np.square(PHV3DBsmooth[k]).sum(axis=1).sum(axis=1)[3:-3]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(PHV3DB_Energy[E_name])

#plot 2:
plt.subplot(1, 2, 2)
plt.plot(PHV3DBsmooth_Energy[E_name])

# %% [markdown]
# # Normalization

# %%
PHV2DBnormalized_Energy={}
for k in PHV2DBsmooth.keys():
   PHV2DBnormalized_Energy[k]=(PHV2DBsmooth_Energy[k]-np.min(PHV2DBsmooth_Energy[k]))/(np.max(PHV2DBsmooth_Energy[k])-np.min(PHV2DBsmooth_Energy[k]))

# %%
PHV3DBnormalized_Energy={}
for k in PHV3DBsmooth.keys():
   PHV3DBnormalized_Energy[k]=(PHV3DBsmooth_Energy[k]-np.min(PHV3DBsmooth_Energy[k]))/(np.max(PHV3DBsmooth_Energy[k])-np.min(PHV3DBsmooth_Energy[k]))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(PHV3DBsmooth_Energy[E_name])

#plot 2:
plt.subplot(1, 2, 2)
plt.plot(PHV3DBnormalized_Energy[E_name])

# %% [markdown]
# ##Segmentation

# %%
Threshold = 0.2

# %%
PHV2DBnormalized_Mask={}
for k in PHV2DBsmooth.keys():
  PHV2DBnormalized_Mask[k]=PHV2DBnormalized_Energy[k]>Threshold

# %%
PHV3DBnormalized_Mask={}
for k in PHV3DBsmooth.keys():
  PHV3DBnormalized_Mask[k]=PHV3DBnormalized_Energy[k]>Threshold

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(PHV3DBnormalized_Energy[E_name])

#plot 2:
plt.subplot(1, 2, 2)
plt.plot(PHV3DBnormalized_Mask[E_name])

# %% [markdown]
# Moving Average function

# %%
def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
PHV2DBnormalized_MaskMovingAverage={}
for k in PHV2DBnormalized_Mask.keys():
  PHV2DBnormalized_MaskMovingAverage[k]=moving_average(PHV2DBnormalized_Mask[k],50)

# %%
PHV3DBnormalized_MaskMovingAverage={}
for k in PHV3DBnormalized_Mask.keys():
  PHV3DBnormalized_MaskMovingAverage[k]=moving_average(PHV3DBnormalized_Mask[k],50)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
plt.plot(PHV3DBnormalized_Energy[E_name])

#plot 2:
plt.subplot(1, 3, 2)
plt.plot(PHV3DBnormalized_Mask[E_name])

#plot 3:
plt.subplot(1, 3, 3)
plt.plot(PHV3DBnormalized_MaskMovingAverage[E_name])

# %%
PHV2DBnormalized_MaskModified={}
for k in PHV2DBnormalized_Mask.keys():
  PHV2DBnormalized_MaskModified[k]=PHV2DBnormalized_MaskMovingAverage[k]>0.7

# %%
PHV3DBnormalized_MaskModified={}
for k in PHV3DBnormalized_Mask.keys():
  PHV3DBnormalized_MaskModified[k]=PHV3DBnormalized_MaskMovingAverage[k]>0.7

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 6))
plt.subplot(1, 4, 1)
plt.plot(PHV3DBnormalized_Energy[E_name])

#plot 2:
plt.subplot(1, 4, 2)
plt.plot(PHV3DBnormalized_Mask[E_name])

#plot 3:
plt.subplot(1, 4, 3)
plt.plot(PHV3DBnormalized_MaskMovingAverage[E_name])

#plot 4:
plt.subplot(1, 4, 4)
plt.plot(PHV3DBnormalized_MaskModified[E_name])

# %% [markdown]
# Compute the first derivative of PHV2DBsmooth and PHV3DBsmooth .... if needed

# %%
PHV3DBsmooth_1std={}
for k in PHV3DBsmooth.keys():
  for frame_cnt in range(2,PHV3DBsmooth[k].shape[0]-2):
    if frame_cnt == 2:
      tmp=PHV3DBsmooth[k][frame_cnt-1]-PHV3DBsmooth[k][frame_cnt]
      tmp = tmp[np.newaxis,:,:]
    else:
      tmp2=PHV3DBsmooth[k][frame_cnt-1]-PHV3DBsmooth[k][frame_cnt]
      tmp2= tmp2[np.newaxis,:,:]
      tmp=np.concatenate((tmp,tmp2))
  PHV3DBsmooth_1std[k]=tmp

# %%
PHV2DBsmooth_1std={}
for k in PHV2DBsmooth.keys():
  for frame_cnt in range(2,PHV2DBsmooth[k].shape[0]-2):
    if frame_cnt == 2:
      tmp=PHV2DBsmooth[k][frame_cnt-1]-PHV2DBsmooth[k][frame_cnt]
      tmp = tmp[np.newaxis,:,:]
    else:
      tmp2=PHV2DBsmooth[k][frame_cnt-1]-PHV2DBsmooth[k][frame_cnt]
      tmp2= tmp2[np.newaxis,:,:]
      tmp=np.concatenate((tmp,tmp2))
  PHV2DBsmooth_1std[k]=tmp

# %% [markdown]
# Compute the second derivative of PHV2DBsmooth and PHV3DBsmooth  .... if needed

# %%
PHV3DBsmooth_2ndd={}
for k in PHV3DBsmooth.keys():
  for frame_cnt in range(2,PHV3DBsmooth[k].shape[0]-2):
    if frame_cnt == 2:
      tmp=PHV3DBsmooth[k][frame_cnt-2]+PHV3DBsmooth[k][frame_cnt+2]-2*PHV3DBsmooth[k][frame_cnt]
      tmp = tmp[np.newaxis,:,:]
    else:
      tmp2=PHV3DBsmooth[k][frame_cnt-2]+PHV3DBsmooth[k][frame_cnt+2]-2*PHV3DBsmooth[k][frame_cnt]
      tmp2= tmp2[np.newaxis,:,:]
      tmp=np.concatenate((tmp,tmp2))
  PHV3DBsmooth_2ndd[k]=tmp

# %%
PHV2DBsmooth_2ndd={}
for k in PHV2DBsmooth.keys():
  for frame_cnt in range(2,PHV2DBsmooth[k].shape[0]-2):
    if frame_cnt == 2:
      tmp=PHV2DBsmooth[k][frame_cnt-2]+PHV2DBsmooth[k][frame_cnt+2]-2*PHV2DBsmooth[k][frame_cnt]
      tmp = tmp[np.newaxis,:,:]
    else:
      tmp2=PHV2DBsmooth[k][frame_cnt-2]+PHV2DBsmooth[k][frame_cnt+2]-2*PHV2DBsmooth[k][frame_cnt]
      tmp2= tmp2[np.newaxis,:,:]
      tmp=np.concatenate((tmp,tmp2))
  PHV2DBsmooth_2ndd[k]=tmp
